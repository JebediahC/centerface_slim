# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("image/20_Family_Group_Family_Group_20_43.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# from utils import VisionKit
# from config import Config
# cfg = Config()
# vk = VisionKit()
# canvas = vk.letterbox(img,cfg.insize)

# %%
from datasets import WiderFace
from config import Config as cfg
widerface = WiderFace(cfg.dataroot, cfg.annfile, cfg.sigma, cfg.downscale, cfg.insize, cfg.train_transforms)

# %%
import torchvision.transforms as trfs
im, hm = widerface.__getitem__(2)
pil_im = trfs.ToPILImage()(im)
pil_im
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7F585922FAC0>

# %%
plt.imshow(hm[0])

# %%
plt.imshow(hm[5])

# %%
im, hm = widerface.__getitem__(10969)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/jebediahc/Deep-Learning/my_centerface/quick_run.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jebediahc/Deep-Learning/my_centerface/quick_run.ipynb#ch0000007vscode-remote?line=0'>1</a> im, hm = widerface.__getitem__(10969)
#
# File ~/Deep-Learning/my_centerface/datasets.py:37, in WiderFace.__getitem__(self, idx)
#      <a href='file:///home/jebediahc/Deep-Learning/my_centerface/datasets.py?line=34'>35</a> anns = self.annslist[idx]
#      <a href='file:///home/jebediahc/Deep-Learning/my_centerface/datasets.py?line=35'>36</a> im, bboxes, landmarks = self.preprocess(im, anns)
# ---> <a href='file:///home/jebediahc/Deep-Learning/my_centerface/datasets.py?line=36'>37</a> hm = self.make_heatmaps(im, bboxes, landmarks, self.downscale)
# ...
